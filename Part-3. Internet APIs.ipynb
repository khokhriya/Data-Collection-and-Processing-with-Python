# %% [markdown]
# ## Requesting Data from the Internet

# %% [markdown]
# ## Practice with REST APIs

# %% [markdown]
# protocol://{servers} / {argument}

# %% [markdown]
# ### 2. The Internet: Behind the Scenes

# %% [markdown]
# #### Routing and ROuters

# %% [markdown]
#  * The computing devices that do that packet forwarding are called routers.

# %% [markdown]
# * Forward Packets, Best path

# %% [markdown]
#  #### The Internet is a transport mechanism that lets any connected device communicate with any other connected device.

# %% [markdown]
# * Translate domain name to IP Address

# %% [markdown]
# * Open a connection
#
#       set an encryption key if https

# %% [markdown]
# * Start sending messesags using the protocol

# %% [markdown]
#          * GET {ARGUMENTS}
#          * RECEIVE HTML

# %% [markdown]
# ### 3. Anatomy of URLs

# %% [markdown]
# The overall structure of a URL is:

# %% [raw]
# <scheme>://<host>:<port>/<path>

# %% [markdown]
# #### schemes

# %% [markdown]
# * http or https (s for secure)

# %% [markdown]
# * ftp (for file transfer)

# %% [markdown]
# * mailto (for email addresses)

# %% [markdown]
# “query parameters”

# %% [markdown]
# Domain Name System(DNS)

# %% [markdown]
# #### :port

# %% [markdown]
#  it is optional. If it is omitted, the default port number is 80. The port number is used on the receiving end to decide which computer program should get the data that has been received.

# %% [markdown]
# #### /path

# %% [markdown]
#  /path is also optional. It specifies something about which page, or more generally which contents, are being requested.

# %% [markdown]
# ### 4. The HTTP protocol

# %% [markdown]
# ####  Step 1: the client makes a request to the server.

# %% [markdown]
# * GET path
# * POST

# %% [markdown]
# #### Step 2: the server responds to the client.

# %% [markdown]
# * HTTP headers

# %% [markdown]
# ### 5. Using REST APIs

# %% [markdown]
# * REST stands for REpresentational State Transfer

# %% [markdown]
# * API stands for Application Programming Interface

# %% [markdown]
# * a REST API specifies how external programs can make HTTP requests to a web site in order to request that some computation be carried out and data returned as output.

# %% [markdown]
# #### web service
# When a website is designed to accept requests generated by other computer programs, and produce outputs to be consumed by other programs, it is sometimes called a web service

# %% [markdown]
# #### web site
# a web site which produces output meant for humans to consume in a web browser.

# %% [markdown]
# #### URL Structure for REST APIs
#
# * The base URL
#
# * A ? character
#
# * One or more key-value pairs, formatted as key=value pairs and separated by the & character.

# %% [markdown]
# #### “encoding” URL parameters.
#
# * The base URL is https://www.google.com/search
# * ?
# * Two key=value parameters, separated by &
#
#       q=%22violins+and+guitars%22 says that the query to search for is “violins and guitars”.
#
#       tbm=isch says to go to the tab for image search

# %% [markdown]
# ## Using REST APIs

# %% [markdown]
# ### 6. Fetching a page

# %% [markdown]
# #### More Details of Response objects

# %% [markdown]
# * The .text attribute. It contains the contents of the file or other information available from the url (or sometimes an error message).
#
# * The .url attribute. We will see later that requests.get takes an optional second parameter that is used to add some characters to the end of the base url that is the first parameter. The .url attribute displays the full url that was generated from the input parameters. It can be helpful for debugging purposes; you can print out the URL, paste it into a browser, and see exactly what was returned.
#
# * The .json() method. This converts the text into a python list or dictionary, by passing the contents of the .text attribute to the jsons.loads function.

# %% [markdown]
# * The .status_code attribute.
#
#       code 200=== A server thinks that it is sending back what was requested
#
#       code 404=== File Not Found
#
#       code 301=== it looks at the new url and fetches it
#
#       code 200=== fetches the other url

# %% [markdown]
# .text
#
# .url
#
# .json()
#
# .status_code (not available in Runestone implementation)
#
# .headers (not available in Runestone implementation)
#
# .history

# %% [markdown]
# #### Using requests.get to encode URL parameters

# %% [markdown]
# ### 8. Figuring Out How to Use a REST API

# %% [markdown]
# * What is the baseurl?
#
# * What keys should you provide in the dictionary you pass for the params parameter?
#
# * What values should you provide associated with those keys?
#
# * Do you need to authenticate yourself as a licensed user of the API and, if so, how?
#
# * What is the structure and meaning of the data that will be provided?

# %% [markdown]
# Example: the datamuse API
#
# Defining a function to make repeated invocations

# %% [markdown]
# ### 9. Debugging calls to requests.get()

# %% [markdown]
# There are two possibilities for what’s gone wrong in that case

# %% [markdown]
# * One possibility is that the value provided for the params parameter is not a valid dictionary or doesn’t have key-value pairs that can be converted into text strings suitable for putting into a URL

# %% [markdown]
# * The second possibility is that the variable dest_url is either not bound to a string, or is bound to a string that isn’t a valid URL

# %% [markdown]
# ### 10. Requests Cookbook

# %% [markdown]
# The basic process involves three steps:
#
# * Make the appropriate call to requests.get(). If you have trouble, print out the URL that’s generated and work with it in the browser.
#
# * Extract content from response object, by accessing the .text attribute and calling json.loads if the string is in json format.
#
# * Process the data you’ve extracted. Often, when you get back data in json format, it will be a highly nested data structure. You may only need a little of that data. You may want to review the chapter on nested data and nested iteration, especially the section on the cycle of Understand. Extract. Repeat.

# %% [markdown]
# ### 11. Searching for Media on iTunes

# %% [markdown]
# ### 12. Searching for tags on flickr
